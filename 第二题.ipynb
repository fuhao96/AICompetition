# %% [markdown]
# # 第二题： 飞机目标检测
#  <hr style=" height:2px " />
#
# #### 项目背景：物体检测和识别是计算机视觉中的常见应用。例如，为了辨别目标图片上是否存在特定的物体，需要进行针对性的特征提取，分析处理等操作。
# #### 任务描述：飞机已经成为远途旅行必不可少的工具，如果仅靠黑匣子中的定位系统，容易发生故障后失联的情况。某机场采用卫星遥感技术对飞机进行目标定位，使用人工智能系统自动检测飞机位置，便于精确掌握飞机的空间位置，还便于统计进出机场的飞机数量，从而实现机场对飞机进行精准管理。
#
# #### 项目要求： 通过图片进行处理，检测并标记出图片中的飞机。
# #### 数据集：
# - 训练集地址： /data/saia/0202/dataset1K.zip （为zip压缩文件）
# - 测试集地址： /data/saia/0202/dataset300.zip （为zip压缩文件）
# - 飞机检测数据集是带有飞机类型和边界框注释的飞机图像集合。
# - PASCAL VOC 格式的边界框（xmin、ymin、xmax、ymax）
# - 35种飞机类型（A10、AG600、B1、B2、B52 Be200、C130、C17、C5、E2、EF2000、F117、F14、F15、F16、F18、F22、F35、F4、J20、JAS39、Mi310MQ29、Mirage , RQ4, Rafale, SR71(可能含有A12), Su57, Tu160, Tu95(可能含有Tu142), U2, US2, V22, XB70, YF23)
# # 类别映射
# category_mapping = {
#     "A10": 1,
#     "AG600": 2,
#     "B1": 3,
#     "B2": 4,
#     "B52": 5,
#     "Be200": 6,
#     "C130": 7,
#     "C17": 8,
#     "C5": 9,
#     "E2": 10,
#     "EF2000": 11,
#     "F117": 12,
#     "F14": 13,
#     "F15": 14,
#     "F16": 15,
#     "F18": 16,
#     "F22": 17,
#     "F35": 18,
#     "F4": 19,
#     "J20": 20,
#     "JAS39": 21,
#     "Mi310MQ29": 22,
#     "Mirage": 23,
#     "RQ4": 24,
#     "Rafale": 25,
#     "SR71(可能含有A12)": 26,
#     "Su57": 27,
#     "Tu160": 28,
#     "Tu95(可能含有Tu142)": 29,
#     "U2": 30,
#     "US2": 31,
#     "V22": 32,
#     "XB70": 33,
#     "YF23": 34
# }
# 如何找到数据集：
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# ![image-3.png](attachment:image-3.png)
#
# ![image-6.png](attachment:image-6.png)

# %% [markdown]
# #### 数据集内容示意图如下：
# ![image.png](attachment:d21c28be-970f-4f18-adaa-bb3a797df7b5.png)

# %% [markdown]
# #### csv 文件中储存着对应的图片信息，其中包含：图片名、图片宽高、目标类别以及目标坐标（xmin、ymin、xmax、ymax），如下：
# ![image.png](attachment:22a90a95-3365-4691-95ae-9167b3c0d983.png)

# %% [markdown]
# ###  <u>模块D  计算机视觉需求分析与解决方案设计 <u>
#
# #### 模块建议时长：30分钟
# #### 模块分数：10分
# #### 要求：用文字方式对项目进行需求分析和解决方案设计。内容包括但不限于：
# - 针对业务实际需求，对计算机视觉应用工具或产品数据进行分析。
# - 通过分析，将业务需求转化为可实现的技术方案，判断并选择所需要的模型。
# - 对关键参数的调整和适配提出解决设想。
# - 设计算法模型的搭建、训练、 测试的方法和技术细节。
# - 设计算法模型的性能评价方式。

# %% [markdown]
# ### <font color='#FF0000'>“模块D 计算机视觉需求分析与解决方案设计”答题处： </font>
#
# #### <font color='#FF0000'> 请编辑此单元，对项目需求分析和解决方案进行描述（不超过1000字） </font>
#
# #### 答：
# ####
# ####
# ####
# ####
# ####
# ####
# ####

# %% [markdown]
# ###  <u>模块E 计算机视觉模块开发与优化 <u>
#
# #### 模块建议时长：80分钟
# #### 模块分数：35分
# #### 要求：自行选择熟悉的开发框架。使用常见的算法模型，将业务需求转化为可实现的技术方案，开发计算机视觉模块，并根据需要进行模型优化。（1）完成项目要求，使用dataset1K.zip作为训练集，检测并标记出图片中的飞机。（2）使用dataset300.zip作为测试集，制定合理的性能评价指标，并输出性能评价指标（须包括准确率和总运行时长）。

# %% [markdown]
# ###  <font color='#FF0000'> “模块E 自然语言处理模块开发与优化”代码实现：</font>

# %%
# 请在本代码块中添加代码，也可以根据需要自行新增代码块

# %% [markdown]
# 有概率因为运行人数过多，资源过大，将无法进行预测，请过几分钟后重试

# %% [markdown]
# ###  <u>模块F 计算机视觉系统分析与运维 <u>
#
# #### 模块建议时长：40分钟
# #### 模块分数：5分
# #### 要求：（1）针对选择的算法模型，对计算机视觉系统模型、算法或系统的性能进行评估。（2）设计系统的运行维护方案。（不超过800字）
# #### 答：
# ####
# ####
# ####
# ####
# ####

# %% [markdown]
# ####  先csv转Yolo数据集
#
# 直接yolov8
#
# 性能以mAP之类的评估
#
# ---------------------
#
# 项目需求分析和解决方案设计：
#
# 针对业务实际需求，我们需要设计一个飞机目标检测系统，能够对输入的图片进行处理，检测并标记出图片中的飞机。为了实现这一目标，我们需要进行以下步骤：
#
# 计算机视觉应用工具和数据分析：
# 针对飞机目标检测任务，我们可以分析计算机视觉领域的相关工具和技术。目标检测是一个常见的计算机视觉任务，有多种方法可以实现，包括基于传统机器学习的方法和基于深度学习的方法。考虑到深度学习在目标检测任务上的优越性能，我们可以选择使用基于深度学习的目标检测模型。
#
# 技术方案选择：
# 针对飞机目标检测任务，我们可以选择使用Yolov8作为解决方案。Yolov8是一种先进的目标检测算法，具有高度的准确性和实时性能。它使用深度卷积神经网络（CNN）来实现目标检测，并通过对图像进行多尺度特征提取和预测来实现对不同大小的飞机目标的准确检测。
#
# 关键参数调整和适配设想：
# 在使用Yolov8进行飞机目标检测时，我们需要根据具体情况对一些关键参数进行调整和适配。例如，我们可以调整检测模型的输入分辨率，以适应不同图片的尺寸变化。同时，我们也可以调整目标检测模型的置信度阈值和非最大抑制（NMS）的参数，以平衡准确率和召回率，并去除重叠的检测框。
#
# 算法模型的搭建、训练和测试：
# 在算法模型的搭建方面，我们需要使用预训练的Yolov8模型作为基础，并根据实际需求对模型进行微调和训练。为了训练模型，我们需要准备标注好的飞机目标的训练数据集，并进行数据增强操作，以扩充数据集和提高模型的泛化能力。
#
# 在训练过程中，我们可以使用常见的优化算法如随机梯度下降（SGD）来更新模型参数，并使用交叉熵损失函数来衡量模型预测结果与真实标签的差异。训练完成后，我们需要对模型进行测试，使用测试数据集评估模型的性能和准确度。
#
# 算法模型的性能评价方式：
# 针对飞机目标检测任务，我们可以使用多种性能评价指标来衡量模型的准确性和鲁棒性。常见的指标包括精确率（Precision）、召回率（Recall）和F1值（F1-score）。精确率衡量模型检测出的飞机目标中的正确性，召回率衡量模型检测出的飞机目标与实际飞机目标的比例，F1值综合考虑了精确率和召回率。除此之外，还可以考虑计算平均准确率均值（mAP）等指标，以综合评估模型的性能。
#
# 通过以上设计方案，我们可以搭建一个飞机目标检测系统，利用Yolov8模型进行飞机目标的准确检测和标记。同时，我们可以根据实际需求对模型的参数进行调整和适配，并使用合适的评价指标对模型的性能进行评估和优化。这样的系统可以帮助机场实现对飞机的精准管理和统计，提高安全性和效率。
#
# ----------------------------------------------------------------------
#
# 根据选择的算法模型进行计算机视觉系统的性能评估，可以采用以下方法：
#
# 准确率和召回率评估：对于飞机目标检测任务，可以计算模型的准确率和召回率。准确率表示模型检测出的飞机目标中有多少是真正的飞机，召回率表示模型能够检测出多少真实的飞机目标。通过计算这两个指标，可以评估模型的精度和召回能力。
#
# F1值评估：F1值综合考虑了准确率和召回率，是一个综合评价模型性能的指标。F1值越高，表示模型在准确性和召回率之间取得了较好的平衡。
#
# mAP评估：mAP（mean Average Precision）是用于评估目标检测任务性能的重要指标。mAP考虑了不同置信度阈值下的准确率和召回率，并计算其均值。较高的mAP值表示模型在不同置信度阈值下具有较好的准确性和召回率表现。
#
# 速度和实时性评估：对于飞机目标检测系统，除了准确率和召回率外，还需要评估系统的速度和实时性。可以统计模型处理单张图片的平均耗时，以及在给定时间内能够处理的图片数量，以评估系统的实时性能。
#
# 根据性能评估结果，可以对计算机视觉系统的性能进行总结和评价。如果模型在准确率、召回率和F1值等指标上表现较好，并且能够在较短的时间内实现实时处理，那么系统性能较好。反之，如果模型的性能不达标，可能需要进行进一步的调优或更换更适合的模型。
#
# 设计系统的运行维护方案：
#
# 为了确保计算机视觉系统的稳定运行和持续性能提升，可以考虑以下运行维护方案：
#
# 定期数据更新：定期更新训练数据集，以保证模型对新数据具有良好的泛化能力。收集新的飞机图片并进行标注，将其加入训练数据集中，以便模型能够学习到更多样化的飞机目标。
#
# 模型更新和迭代：随着技术的进步和业务需求的变化，可能需要定期更新模型，引入更先进的目标检测算法或网络架构。通过迭代更新模型，可以不断提高系统的性能和准确率。
#
# 异常数据处理：对于检测到的异常数据和错误标记，需要进行人工验证和纠正，以提高系统的准确性。建立反馈机制，及时收集用户的反馈和建议，并进行相应的优化和改进。
#
# 系统监控和故障排除：建立监控系统，实时监测计算机视觉系统的运行状态，包括模型的预测性能、资源利用情况等。及时发现和解决系统故障，确保系统的稳定运行。
#
# 安全和隐私保护：对于涉及敏感信息的飞机目标检测系统，需要采取相应的安全措施，确保数据的安全和隐私保护。加密传输数据、访问控制和权限管理等措施是保护系统安全和用户隐私的关键步骤。
#
# 通过以上的运行维护方案，可以确保计算机视觉系统的稳定运行，持续提升系统性能和准确性，以满足飞机目标检测的实际需求。
# ####
# ####
# ####

# %% [markdown]
# ### <font color='#FF0000'>注意：完成后请注意保存文件。答题完成后请不要关闭本题窗口，须保持本题为打开状态。</font>
